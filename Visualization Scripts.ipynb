# %%
#Visualization

# %%
import pandas as pd
import numpy as np

import random

# %%
#Reading excelfiles to create dataframe1
df1 = pd.read_excel(r"C:\Users\Dell\Documents\Massdoc.xlsx")

#Reading excelfiles to create dataframe2
df2=pd.read_excel(r"C:\Users\Dell\Downloads\zocdoc.xlsx")
#Cleaing the data

#1.Cleaning the doctor name column by spliting it into Doctor_Nmae and Degree
df2['Doctor_Name'].str.split(',',n=1)
df2[['Doctor_Name','Degree']] = df2['Doctor_Name'].str.split(',', n=1, expand=True)

#2.Concating two data frames for doctors since data is collected from two different sources
df3=pd.concat([df1,df2])

#3.Filling Nan with Unknown for those doctors who dont have License Number
df4=df3.fillna({'License Number':'Unknown'})

#4. Populating Gender column where gender is Nan
df4['Gender'] = pd.Series(
    random.choices(['Male', 'Female','Transgender'], weights=[1, 1,1], k=len(df4)),
    index=df4.index
)

# %%
print(df4)
# Out:
#     Doctor_Id  License_Number          Doctor_Name                   Degree  \
# 0           1         54713.0            Ward Bein  M.D. or M.D. Equivalent
# 1           2         58952.0        Donald Condie  M.D. or M.D. Equivalent
# 2           3         51517.0     Jeffrey Friedman  M.D. or M.D. Equivalent
# 3           4        255819.0          Mihae Platt  M.D. or M.D. Equivalent
# 4           5        288074.0     Allison Nussbaum                     D.O.
# ..        ...             ...                  ...                      ...
# 46       1022             NaN      Irving Weissman                       MD
# 47       1023             NaN        Nedda Sanayei                       MD
# 48       1024             NaN         Poonam Doshi                       MD
# 49       1025             NaN        Nina Farivari                       MD
# 50       1026             NaN   Chelsea Gottschalk                       MD
#
#                                 Practice_Specialities       Gender
# 0   Child and Adolescent Psychiatry, Psychiatry, F...         Male
# 1   Child and Adolescent Psychiatry, Psychiatry, F...         Male
# 2   Forensic Psychiatry, Psychiatry, Geriatric Psy...       Female
# 3   Medical Microbiology Pathology, Pathology, Mol...         Male
# 4   Child and Adolescent Psychiatry, Psychiatry, P...  Transgender
# ..                                                ...          ...
# 46                                    Ophthalmologist  Transgender
# 47                                    Ophthalmologist       Female
# 48                                    Ophthalmologist       Female
# 49                                    Ophthalmologist       Female
# 50                                    Ophthalmologist         Male
#
# [1026 rows x 6 columns]

# %%
import seaborn as sns
sns.countplot(df4['Gender'])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot(df4['Degree'])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Degree', ylabel='count'>

# %%
df5 = pd.read_excel(r"C:\Users\Dell\Documents\Hospitals.xlsx")

#9.Cleaning ZipCode column to remove unwanted values
df5['ZipCode'] = df5['Zip_Code'].astype(str).str[:4]
df5=df5.drop(['Zip_Code'],axis=1)
print(df5)
# Out:
#       Hospital_Id                              Hospital_Affiliations  \
# 0               1               Tewksbury Hospital, Private Practice
# 1               2  Private Office, People Care Clinic, Vinfen Cor...
# 2               3  Mount Auburn Hospital, Brigham & Women's Hospi...
# 3               4                            Quest Diagnostics, Inc.
# 4               5  Cambridge Health Alliance - Somerville Campus,...
# ...           ...                                                ...
# 1061         1062                                       Lahey Clinic
# 1062         1063                              Mount Auburn Hospital
# 1063         1064                               South Shore Hospital
# 1064         1065  Beth Israel Deaconess Medical Center, Cambridg...
# 1065         1066                              Mount Auburn Hospital
#
#              City State ZipCode
# 0           Acton    MA    1720
# 1       Cambridge    MA    2141
# 2       Cambridge    MA    2139
# 3     Marlborough    MA    1752
# 4       cambridge    MA    2139
# ...           ...   ...     ...
# 1061   Burlington    MA    1803
# 1062    Cambridge    MA    2238
# 1063    Cambridge    MA    2142
# 1064    Cambridge    MA    2142
# 1065    Cambridge    MA    2139
#
# [1066 rows x 5 columns]

# %%
sns.countplot(df5['City'])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='City', ylabel='count'>
